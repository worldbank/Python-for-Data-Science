# %% [markdown]
# # Week 4 - EXERCISE 1
#
# Run through these exercises to consolidate the material covered so far. Do all the tasks outlined in bold, asking Google for help where needed.

# %% [markdown]
# ## 1.1 Variables, string manipulation

# %% [markdown]
# **Combine these four variables into a single string and print it.**

# %%
a = 'Welcome to '
b = 'Python class '
c = 'week '
d = 4

# %%
# YOUR CODE HERE
print(a + b + c + str(d))
# Out:
# Welcome to Python class week 4

# %% [markdown]
# **Multiply d by 10 and print the sentence again.**

# %%
# YOUR CODE HERE
d = d * 10
print(a + b + c + str(d))
# Out:
# Welcome to Python class week 40

# %% [markdown]
# **Print both of the following**:
#
#     Nick says "hello"
#     This is Dharana's sandwich
# Explanation [here](https://docs.python.org/2.0/ref/strings.html) if needed.

# %%
print('Charles says "hello"')
print("This is Dharana's sandwich")
# print('''This is Dharana's sandwich''')    or this version
# print('This is Dharana\'s sandwich')       or this one
# Out:
# Charles says "hello"
# This is Dharana's sandwich

# %% [markdown]
# **Write a program to print "Welcome to beautiful {country}!" for each country in the list.**

# %%
country_list = ['Kazakhstan','Kenya', 'Kiribati', "Korea (DPRK)", 'Korea (ROC)', 'Kosovo', 'Kuwait', 'Kyrgyzstan']

# %%
# YOUR CODE HERE:
for country in country_list:
    print("Welcome to beautiful {}!".format(country))
# Out:
# Welcome to beautiful Kazakhstan!
# Welcome to beautiful Kenya!
# Welcome to beautiful Kiribati!
# Welcome to beautiful Korea (DPRK)!
# Welcome to beautiful Korea (ROC)!
# Welcome to beautiful Kosovo!
# Welcome to beautiful Kuwait!
# Welcome to beautiful Kyrgyzstan!

# %% [markdown]
# **Write a function to test whether the word dragon is in a string**

# %%
# YOUR FUNCTION HERE:
def check_for_dragons(string_to_test):
    return('dragon' in string_to_test)

# %%
from IPython.display import Image
Image(filename='village.jpg', width = 250)

# %%
check_for_dragons('Under the bridge at Pontrhydfendigaid lies a dragon')
# Out:
# True

# %% [markdown]
# **Split the string below into a list of words, then:**
# * print only the second to fifth items in the list
# * count the items in the list
# * use list indexing to replace "dog" with "dinosaur"

# %%
rhyme = "The quick brown fox jumps over the lazy dog"

# YOUR CODE HERE:

my_list = rhyme.split()
my_list
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
my_list[1:4]
# Out:
# ['quick', 'brown', 'fox']

# %%
len(my_list)
# Out:
# 9

# %%
my_list[8] = 'dinosaur'
my_list
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dinosaur']

# %% [markdown]
# **Create a function to replace 'not bad' with 'really good' in a string, and add exclamation marks. Your function takes two parameters: my_string and number_exclamation_marks.** Bonus: apply it to each of the three strings using a for loop, adding a random number of exclamation marks.

# %%
# YOUR FUNCTION HERE:
def add_enthusiasm(my_string, number_exclamation_marks):
    my_string = my_string.replace('not bad', 'really good') + '!' * number_exclamation_marks
    return(my_string)

# %%
string1 = 'This chicken curry is not bad'
string2 = "Nick's ukulele playing is not bad"
string3 = 'DC United are not bad'

# %%
add_enthusiasm(string1, 3)
# Out:
# 'This chicken curry is really good!!!'

# %%
for string in [string1, string2, string3]:
    print(add_enthusiasm(string, random.randint(0,10)))
# Out:
# This chicken curry is really good!!!!!!
# Nick's ukulele playing is really good!!
# DC United are really good!

# %% [markdown]
# ## 1.2 Lists and dictionaries

# %% [markdown]
# **Sort these albums into alphabetical order.**

# %%
albums = ['Piper At The Gates of Dawn',
          'Ummagumma',
          'Obscured By Clouds',
          'Dark Side Of The Moon']

# %%
# YOUR CODE HERE:
sorted(albums)
# Out:
# ['Dark Side Of The Moon',
#  'Obscured By Clouds',
#  'Piper At The Gates of Dawn',
#  'Ummagumma']

# %% [markdown]
# **They were recorded in 1967, 1969, 1972 and 1973 respectively. Make a dictionary called album_dict where the key-value pairs are album name and date. Check it worked by retrieving the date of Ummagumma.**

# %%
# YOUR CODE HERE

album_dict = {'Piper At The Gates of Dawn': 1967,
             'Ummagumma': 1969,
              'Obscured By Clouds': 1972,
              'Dark Side Of The Moon': 1973}

album_dict['Ummagumma']
# Out:
# 1969

# %% [markdown]
# **Given this nested list, grab the word dragon**

# %%
my_list = [0,4,[4,3,2],[420, 250, [1,2,3,'dragon']],365,23,6]

# %%
my_list[3][2][3]
# Out:
# 'dragon'

# %% [markdown]
# **Write a program to iterate through `shopping_list` (a dictionary containing items and their price). As each item is added, print its name and the running total. If an item cost more than 15 dollars, print "Warning: expensive!"**

# %%
shopping_list = {'green eggs': 3.09,
                'ham': 5.99,
                'christmas tree': 45.00,
                'caviar': 299.99,
                'newspaper': 3.50}

total = 0
for item,price in shopping_list.items():
    total += price
    print(item)
    print("total so far: ", total)
    if price > 15:
        print('---> Warning: expensive!')
    print()
# Out:
# green eggs
# total so far:  3.09
#
# ham
# total so far:  9.08
#
# christmas tree
# total so far:  54.08
# ---> Warning: expensive!
#
# caviar
# total so far:  354.07
# ---> Warning: expensive!
#
# newspaper
# total so far:  357.57

# %% [markdown]
# ## 1.3 Drills with some math

# %% [markdown]
# **What is 5 to the power of 3?**

# %%
5 ** 3
# Out:
# 125

# %% [markdown]
# **For all integers between 1 and 10 inclusive, print the number and its square.** Hint: use the [range() function](https://snakify.org/en/lessons/for_loop_range/).

# %%
# YOUR CODE HERE:

for n in range(1,11):
    print(n, n ** 2)
# Out:
# 1 1
# 2 4
# 3 9
# 4 16
# 5 25
# 6 36
# 7 49
# 8 64
# 9 81
# 10 100

# %% [markdown]
# **Write a program to accept variable `radius` from the user. Calculate the area of the circle of this radius. Limit your output to 2 decimal places.**

# %%
radius = input('What radius circle do you want? >> ')
print("Your circle has area {:.2f}".format(float(radius) * 3.14159 **2))
# Out:
# What radius circle do you want? >> 3
# Your circle has area 29.61

# %% [markdown]
# **Write a function `dice_roll` that rolls two dice and returns the score. The score is the sum of the two numbers rolled. However, if the same number came up on both dice, your score gets doubled (eg. two 3s = 12, two 6s = 24).**

# %%
def roll_dice():
    score_A = random.randint(1,7)
    score_B = random.randint(1,7)
    if score_A == score_B:
        return(2 * (score_A + score_B))
    else:
        return(score_A + score_B)

# %%
roll_dice()
# Out:
# 7

# %% [markdown]
# **Define an empty list `scores`. Run your `roll_dice` function n times in a for loop. Each time, add the new score to the list using the list.append() function. At the end, print out lowest score, highest score, and the mean of all scores. Do this for n = 10, 1000 and 10000.**

# %%
scores = []
for i in range(10):
    scores.append(roll_dice())

print("Lowest score: ", min(scores))
print("Highest score: ", max(scores))
print("Mean score: ", sum(scores) / len(scores))
# Out:
# Lowest score:  4
# Highest score:  12
# Mean score:  7.2

# %%
scores = []
for i in range(100):
    scores.append(roll_dice())

print("Lowest score: ", min(scores))
print("Highest score: ", max(scores))
print("Mean score: ", sum(scores) / len(scores))
# Out:
# Lowest score:  3
# Highest score:  20
# Mean score:  7.59

# %%
scores = []
for i in range(100000):
    scores.append(roll_dice())

print("Lowest score: ", min(scores))
print("Highest score: ", max(scores))
print("Mean score: ", sum(scores) / len(scores))
# Out:
# Lowest score:  3
# Highest score:  24
# Mean score:  8.16228

# %% [markdown]
# **Write a function to count the instances of integer 9 in a list.**

# %%
def count_nines(my_list):
    count = 0
    for item in my_list:
        if item == 9:
            count += 1
    return(count)

# %%
my_list = [0,3,2,4,9,9,3]

# %%
count_nines(my_list)
# Out:
# 2

# %% [markdown]
# **Write a function to calculate compound interest. Variables to take: `principal`, `interest_rate`, `years`. Return the amount of money at the end of the period (ie. the principal plus all accrued interest).**

# %%
# YOUR FUNCTION HERE:

def calculate_compound_interest(principal,interest_rate,years):
    for year in range(years):
        principal = principal * interest_rate
    return(principal)

# %%
principal = 100000
interest_rate = 1.05
years = 10

investment_proceeds = calculate_compound_interest(principal, interest_rate, years)

# %%
print("After {} years at interest rate {}, ${} becomes ${:.2f}".format(
    years,
    interest_rate,
    principal,
    investment_proceeds))
# Out:
# After 10 years at interest rate 1.05, $100000 becomes $162889.46
