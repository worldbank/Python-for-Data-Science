# %%
import requests
import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.geometry import Point
import pylab as plt
# %pylab inline
import mplleaflet as mpll
import seaborn as sns
import osmnx as ox
from IPython.display import Image
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/nicholasjones/anaconda3/envs/GPD_OSM/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# # Week 7 - Further geospatial, APIs, and survey data

# %% [markdown]
# ### Part 1. Getting data from APIs

# %% [markdown]
# #### What are APIs, why use them?

# %% [markdown]
# Companies and organizations make certain data available through their Application Programming Interfaces (APIs). To use an API, you make a request to a remote web server via its HTTP address, and retrieve the data you need.
#
# You can retrieve data from APIs instead of downloading a static file to your hard drive and reading it in. This is helpful where:
# * you want the latest data in real time (eg. stock prices or weather)
# * you want a small, selected piece of data (eg. hospital locations in north Wales)
# * the organization will run its own computations for you (eg. request satellite imagery with cloud cover removed, Planet API; analyze sentiment of a document, IBM Watson API).

# %% [markdown]
# |Example API|Functionality|
# |---|---|
# |Overpass API|Get OpenStreetMap data|
# |Google Maps|Get point of interest locations, create distance features|
# |Yahoo Stock|Get stock prices|
# |Twitter, Youtube, Instagram|Get social media data|
# |World Bank Indicators API|Get data from WDI, Doing Business etc|
# |Socrata|City data portals|

# %% [markdown]
# #### Four steps to using APIs
#
# 1. Read the documentation
#
#   APIs are rules specifying what query you should send, and what format of data the server will return back. You query APIs using an HTTP request (ie. a web address). Read the docs to check (i) what the API can do; (ii) what the HTTP request should look like.
#
# 2. Find the API endpoint
#
#   Examples: http://api.twitter.com, http://api.github.com
#
#
# 3. Try a sample query in your web brower or terminal: `curl <http://...>`
#
#   Queries start with the API endpoint, then add commands using the API's specific format. Send a sample query to see what the output looks like. Normally it will be Javascript Object Notation (JSON) format).
#
#
# 4. Extract the information you need from the JSON.
#
#   Remember JSON is a widely used data interchange format. It gives you nested dictionaries and lists (weeks 2-3).
#
#
# 5. Write some code to send custom requests.
#
#   The `requests` library is a painless way to make HTML requests. Using the API's rules and some lines of code, you can quickly request the precise data you want. There are also API wrappers (small Python libraries that manage API requests for you, providing an easier syntax).

# %% [markdown]
# ### Worked example 1: How many humans in space?
#
# A simple API, created by space travel enthusiasts, is [Open Notify](http://open-notify.org/).
#
#
# YOUR ACTION:
# * Check the website to figure out what's going on: http://open-notify.org/
# * Can you find the endpoint, as an `http://` address?
# * Run the code below, and complete the exercise.

# %%
endpoint_url = 'http://api.open-notify.org/astros.json'

# %%
response = requests.get(endpoint_url)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()
data
# Out:
# {'message': 'success',
#  'number': 6,
#  'people': [{'craft': 'ISS', 'name': 'Oleg Kononenko'},
#   {'craft': 'ISS', 'name': 'David Saint-Jacques'},
#   {'craft': 'ISS', 'name': 'Anne McClain'},
#   {'craft': 'ISS', 'name': 'Alexey Ovchinin'},
#   {'craft': 'ISS', 'name': 'Nick Hague'},
#   {'craft': 'ISS', 'name': 'Christina Koch'}]}

# %% [markdown]
# #### EXERCISE:
# * Print a statement like this: "There are currently x people in space."
# * Then print their names, in alphabetical order. Bonus: as a Pandas DataFrame.

# %% [markdown]
# ## Worked example 2: Mexico open data

# %% [markdown]
# **Objective:** Get data from a national Open Data Portal, convert lat / lon coordinates into a geometry object, plot maps.
#
# YOUR ACTION:
# * Look at the Government of Mexico open data portal: https://datos.gob.mx/.
# * Inspect the Condiciones Atmosfericas link in your web browser or via `curl <url>`.
# * Run the code to request and visualize the data.
# * Spend 5 minutes reading the documentation links.

# %%
endpoint_url = 'https://api.datos.gob.mx/v1/condiciones-atmosfericas'

# %%
response = requests.get(endpoint_url)

# %%
data = response.json()

# %%
data['results']
# Out:
# [{'_id': '5952983359954a0adbf7ab09',
#   'cityid': 'MXAS0002',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'SSE',
#   'probabilityofprecip': '40',
#   'relativehumidity': '90',
#   'name': 'Aguascalientes',
#   'date-insert': '2017-06-27T17:36:43.084Z',
#   'longitude': '-102.296',
#   'state': 'Aguascalientes',
#   'lastreporttime': '20170627T092449Z',
#   'skydescriptionlong': 'Tormentas dispersas',
#   'stateabbr': 'AGU',
#   'tempc': '17',
#   'latitude': '21.87982',
#   'iconcode': '96',
#   'windspeedkm': '6'},
#  {'_id': '5952983359954a0adbf7ab0a',
#   'cityid': 'MXAS0170',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'S',
#   'probabilityofprecip': '60',
#   'relativehumidity': '91',
#   'name': 'Asientos',
#   'date-insert': '2017-06-27T17:36:43.088Z',
#   'longitude': '-102.0893',
#   'state': 'Aguascalientes',
#   'lastreporttime': '20170627T092453Z',
#   'skydescriptionlong': 'Tormentas dispersas',
#   'stateabbr': 'AGU',
#   'tempc': '15',
#   'latitude': '22.23832',
#   'iconcode': '96',
#   'windspeedkm': '5'},
#  {'_id': '5952983359954a0adbf7ab0b',
#   'cityid': 'MXAS0171',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'E',
#   'probabilityofprecip': '60',
#   'relativehumidity': '84',
#   'name': 'Calvillo',
#   'date-insert': '2017-06-27T17:36:43.088Z',
#   'longitude': '-102.7188',
#   'state': 'Aguascalientes',
#   'lastreporttime': '20170627T092453Z',
#   'skydescriptionlong': 'Tormentas dispersas',
#   'stateabbr': 'AGU',
#   'tempc': '19',
#   'latitude': '21.84691',
#   'iconcode': '96',
#   'windspeedkm': '2'},
#  {'_id': '5952983359954a0adbf7ab0c',
#   'cityid': 'MXAS0172',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'S',
#   'probabilityofprecip': '50',
#   'relativehumidity': '83',
#   'name': 'Cosío',
#   'date-insert': '2017-06-27T17:36:43.088Z',
#   'longitude': '-102.3',
#   'state': 'Aguascalientes',
#   'lastreporttime': '20170627T092453Z',
#   'skydescriptionlong': 'Tormentas dispersas',
#   'stateabbr': 'AGU',
#   'tempc': '17',
#   'latitude': '22.36641',
#   'iconcode': '96',
#   'windspeedkm': '3'},
#  {'_id': '5952983359954a0adbf7ab0d',
#   'cityid': 'MXAS0173',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'SSO',
#   'probabilityofprecip': '50',
#   'relativehumidity': '84',
#   'name': 'El Llano',
#   'date-insert': '2017-06-27T17:36:43.089Z',
#   'longitude': '-101.9653',
#   'state': 'Aguascalientes',
#   'lastreporttime': '20170627T092453Z',
#   'skydescriptionlong': 'Tormentas dispersas',
#   'stateabbr': 'AGU',
#   'tempc': '17',
#   'latitude': '21.91887',
#   'iconcode': '96',
#   'windspeedkm': '3'},
#  {'_id': '5952983359954a0adbf7ab0e',
#   'cityid': 'MXAS0174',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'ESE',
#   'probabilityofprecip': '60',
#   'relativehumidity': '90',
#   'name': 'Jesús María',
#   'date-insert': '2017-06-27T17:36:43.089Z',
#   'longitude': '-102.3434',
#   'state': 'Aguascalientes',
#   'lastreporttime': '20170627T092453Z',
#   'skydescriptionlong': 'Tormentas dispersas',
#   'stateabbr': 'AGU',
#   'tempc': '17',
#   'latitude': '21.96127',
#   'iconcode': '96',
#   'windspeedkm': '8'},
#  {'_id': '5952983359954a0adbf7ab0f',
#   'cityid': 'MXAS0175',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'SSE',
#   'probabilityofprecip': '60',
#   'relativehumidity': '85',
#   'name': 'Pabellón de Arteaga',
#   'date-insert': '2017-06-27T17:36:43.089Z',
#   'longitude': '-102.2765',
#   'state': 'Aguascalientes',
#   'lastreporttime': '20170627T092453Z',
#   'skydescriptionlong': 'Tormentas',
#   'stateabbr': 'AGU',
#   'tempc': '17',
#   'latitude': '22.1492',
#   'iconcode': '84',
#   'windspeedkm': '6'},
#  {'_id': '5952983359954a0adbf7ab10',
#   'cityid': 'MXAS0176',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'SSE',
#   'probabilityofprecip': '60',
#   'relativehumidity': '86',
#   'name': 'Rincón de Romos',
#   'date-insert': '2017-06-27T17:36:43.089Z',
#   'longitude': '-102.3231',
#   'state': 'Aguascalientes',
#   'lastreporttime': '20170627T092453Z',
#   'skydescriptionlong': 'Tormentas dispersas',
#   'stateabbr': 'AGU',
#   'tempc': '17',
#   'latitude': '22.22923',
#   'iconcode': '96',
#   'windspeedkm': '3'},
#  {'_id': '5952983359954a0adbf7ab11',
#   'cityid': 'MXAS0177',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'SSE',
#   'probabilityofprecip': '60',
#   'relativehumidity': '89',
#   'name': 'San Francisco de los Romo',
#   'date-insert': '2017-06-27T17:36:43.090Z',
#   'longitude': '-102.2727',
#   'state': 'Aguascalientes',
#   'lastreporttime': '20170627T092453Z',
#   'skydescriptionlong': 'Tormentas',
#   'stateabbr': 'AGU',
#   'tempc': '17',
#   'latitude': '22.07239',
#   'iconcode': '84',
#   'windspeedkm': '8'},
#  {'_id': '5952983359954a0adbf7ab12',
#   'cityid': 'MXAS0178',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'SE',
#   'probabilityofprecip': '70',
#   'relativehumidity': '88',
#   'name': 'San José de Gracia',
#   'date-insert': '2017-06-27T17:36:43.091Z',
#   'longitude': '-102.4156',
#   'state': 'Aguascalientes',
#   'lastreporttime': '20170627T092453Z',
#   'skydescriptionlong': 'Tormentas',
#   'stateabbr': 'AGU',
#   'tempc': '16',
#   'latitude': '22.15022',
#   'iconcode': '84',
#   'windspeedkm': '3'},
#  {'_id': '5952983359954a0adbf7ab13',
#   'cityid': 'MXAS0179',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'SSE',
#   'probabilityofprecip': '60',
#   'relativehumidity': '89',
#   'name': 'Tepezalá',
#   'date-insert': '2017-06-27T17:36:43.091Z',
#   'longitude': '-102.167',
#   'state': 'Aguascalientes',
#   'lastreporttime': '20170627T092453Z',
#   'skydescriptionlong': 'Tormentas dispersas',
#   'stateabbr': 'AGU',
#   'tempc': '16',
#   'latitude': '22.22423',
#   'iconcode': '96',
#   'windspeedkm': '3'},
#  {'_id': '5952983359954a0adbf7ab14',
#   'cityid': 'MXBC0003',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'NNE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '43',
#   'name': 'Ensenada',
#   'date-insert': '2017-06-27T17:36:43.091Z',
#   'longitude': '-116.5951',
#   'state': 'Baja California',
#   'lastreporttime': '20170627T092449Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'BCN',
#   'tempc': '22',
#   'latitude': '31.80894',
#   'iconcode': '85',
#   'windspeedkm': '3'},
#  {'_id': '5952983359954a0adbf7ab15',
#   'cityid': 'MXBC0004',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'ONO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '13',
#   'name': 'Mexicali',
#   'date-insert': '2017-06-27T17:36:43.092Z',
#   'longitude': '-115.4756',
#   'state': 'Baja California',
#   'lastreporttime': '20170627T092450Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'BCN',
#   'tempc': '32',
#   'latitude': '32.64117',
#   'iconcode': '85',
#   'windspeedkm': '3'},
#  {'_id': '5952983359954a0adbf7ab16',
#   'cityid': 'MXBC0005',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'NO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '58',
#   'name': 'Tijuana',
#   'date-insert': '2017-06-27T17:36:43.092Z',
#   'longitude': '-117.0189',
#   'state': 'Baja California',
#   'lastreporttime': '20170627T092451Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'BCN',
#   'tempc': '21',
#   'latitude': '32.53246',
#   'iconcode': '85',
#   'windspeedkm': '2'},
#  {'_id': '5952983359954a0adbf7ab17',
#   'cityid': 'MXBC0180',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'ENE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '23',
#   'name': 'Tecate',
#   'date-insert': '2017-06-27T17:36:43.092Z',
#   'longitude': '-116.6265',
#   'state': 'Baja California',
#   'lastreporttime': '20170627T092450Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'BCN',
#   'tempc': '23',
#   'latitude': '32.57268',
#   'iconcode': '85',
#   'windspeedkm': '3'},
#  {'_id': '5952983359954a0adbf7ab18',
#   'cityid': 'MXBS0006',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'S',
#   'probabilityofprecip': '0',
#   'relativehumidity': '65',
#   'name': 'La Paz',
#   'date-insert': '2017-06-27T17:36:43.093Z',
#   'longitude': '-110.3108',
#   'state': 'Baja California Sur',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Mayormente soleado',
#   'stateabbr': 'BCS',
#   'tempc': '26',
#   'latitude': '24.14222',
#   'iconcode': '65',
#   'windspeedkm': '10'},
#  {'_id': '5952983359954a0adbf7ab19',
#   'cityid': 'MXBS0007',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'S',
#   'probabilityofprecip': '10',
#   'relativehumidity': '68',
#   'name': 'Los Cabos',
#   'date-insert': '2017-06-27T17:36:43.093Z',
#   'longitude': '-109.6947',
#   'state': 'Baja California Sur',
#   'lastreporttime': '20170627T092450Z',
#   'skydescriptionlong': 'Nublado',
#   'stateabbr': 'BCS',
#   'tempc': '26',
#   'latitude': '23.06159',
#   'iconcode': '67',
#   'windspeedkm': '10'},
#  {'_id': '5952983359954a0adbf7ab1a',
#   'cityid': 'MXBS0129',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'NNE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '80',
#   'name': 'Loreto',
#   'date-insert': '2017-06-27T17:36:43.093Z',
#   'longitude': '-111.3433',
#   'state': 'Baja California Sur',
#   'lastreporttime': '20170627T092449Z',
#   'skydescriptionlong': 'Mayormente nublado',
#   'stateabbr': 'BCS',
#   'tempc': '28',
#   'latitude': '26.01278',
#   'iconcode': '69',
#   'windspeedkm': '0'},
#  {'_id': '5952983359954a0adbf7ab1b',
#   'cityid': 'MXBS0182',
#   'validdateutc': '20170627T130000Z',
#   'winddirectioncardinal': 'ONO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '97',
#   'name': 'Comondú',
#   'date-insert': '2017-06-27T17:36:43.093Z',
#   'longitude': '-111.6732',
#   'state': 'Baja California Sur',
#   'lastreporttime': '20170627T092449Z',
#   'skydescriptionlong': 'Mayormente soleado',
#   'stateabbr': 'BCS',
#   'tempc': '19',
#   'latitude': '25.03443',
#   'iconcode': '65',
#   'windspeedkm': '3'},
#  {'_id': '5952983359954a0adbf7ab1c',
#   'cityid': 'MXBS0183',
#   'validdateutc': '20170627T130000Z',
#   'winddirectioncardinal': 'OSO',
#   'probabilityofprecip': '10',
#   'relativehumidity': '65',
#   'name': 'Mulegé',
#   'date-insert': '2017-06-27T17:36:43.093Z',
#   'longitude': '-112.2683',
#   'state': 'Baja California Sur',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Parcialmente nublado',
#   'stateabbr': 'BCS',
#   'tempc': '27',
#   'latitude': '27.33687',
#   'iconcode': '66',
#   'windspeedkm': '8'},
#  {'_id': '5952983359954a0adbf7ab1d',
#   'cityid': 'MXCA0021',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'SSE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '50',
#   'name': 'Camargo',
#   'date-insert': '2017-06-27T17:36:43.094Z',
#   'longitude': '-105.1716',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092450Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '26',
#   'latitude': '27.69496',
#   'iconcode': '85',
#   'windspeedkm': '8'},
#  {'_id': '5952983359954a0adbf7ab1e',
#   'cityid': 'MXCA0022',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'N',
#   'probabilityofprecip': '0',
#   'relativehumidity': '40',
#   'name': 'Chihuahua',
#   'date-insert': '2017-06-27T17:36:43.094Z',
#   'longitude': '-106.0763',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '27',
#   'latitude': '28.63679',
#   'iconcode': '85',
#   'windspeedkm': '2'},
#  {'_id': '5952983359954a0adbf7ab1f',
#   'cityid': 'MXCA0023',
#   'validdateutc': '20170627T130000Z',
#   'winddirectioncardinal': 'NNO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '52',
#   'name': 'Delicias',
#   'date-insert': '2017-06-27T17:36:43.094Z',
#   'longitude': '-105.4711',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092450Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '22',
#   'latitude': '28.19333',
#   'iconcode': '85',
#   'windspeedkm': '5'},
#  {'_id': '5952983359954a0adbf7ab20',
#   'cityid': 'MXCA0024',
#   'validdateutc': '20170627T130000Z',
#   'winddirectioncardinal': 'OSO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '57',
#   'name': 'Hidalgo del Parral',
#   'date-insert': '2017-06-27T17:36:43.095Z',
#   'longitude': '-105.6671',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092450Z',
#   'skydescriptionlong': 'Parcialmente nublado',
#   'stateabbr': 'CHH',
#   'tempc': '19',
#   'latitude': '26.92209',
#   'iconcode': '66',
#   'windspeedkm': '3'},
#  {'_id': '5952983359954a0adbf7ab21',
#   'cityid': 'MXCA0025',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'SSE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '55',
#   'name': 'Jiménez',
#   'date-insert': '2017-06-27T17:36:43.095Z',
#   'longitude': '-104.923',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092450Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '24',
#   'latitude': '27.13055',
#   'iconcode': '85',
#   'windspeedkm': '13'},
#  {'_id': '5952983359954a0adbf7ab22',
#   'cityid': 'MXCA0026',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'ESE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '54',
#   'name': 'Juárez',
#   'date-insert': '2017-06-27T17:36:43.096Z',
#   'longitude': '-106.485',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092449Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '24',
#   'latitude': '31.74647',
#   'iconcode': '85',
#   'windspeedkm': '8'},
#  {'_id': '5952983359954a0adbf7ab23',
#   'cityid': 'MXCA0027',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'SO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '51',
#   'name': 'Nuevo Casas Grandes',
#   'date-insert': '2017-06-27T17:36:43.096Z',
#   'longitude': '-107.9121',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092450Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '23',
#   'latitude': '30.41399',
#   'iconcode': '85',
#   'windspeedkm': '5'},
#  {'_id': '5952983359954a0adbf7ab24',
#   'cityid': 'MXCA0028',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'SO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '64',
#   'name': 'Temósachic',
#   'date-insert': '2017-06-27T17:36:43.096Z',
#   'longitude': '-107.8298',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092450Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '20',
#   'latitude': '28.95276',
#   'iconcode': '85',
#   'windspeedkm': '2'},
#  {'_id': '5952983359954a0adbf7ab25',
#   'cityid': 'MXCA0339',
#   'validdateutc': '20170627T130000Z',
#   'winddirectioncardinal': 'SSE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '69',
#   'name': 'Ahumada',
#   'date-insert': '2017-06-27T17:36:43.096Z',
#   'longitude': '-106.5124',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092451Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '19',
#   'latitude': '30.61773',
#   'iconcode': '85',
#   'windspeedkm': '6'},
#  {'_id': '5952983359954a0adbf7ab26',
#   'cityid': 'MXCA0340',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'N',
#   'probabilityofprecip': '0',
#   'relativehumidity': '47',
#   'name': 'Aldama',
#   'date-insert': '2017-06-27T17:36:43.096Z',
#   'longitude': '-105.9113',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092451Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '26',
#   'latitude': '28.83838',
#   'iconcode': '85',
#   'windspeedkm': '3'},
#  {'_id': '5952983359954a0adbf7ab27',
#   'cityid': 'MXCA0341',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'SSE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '53',
#   'name': 'Allende',
#   'date-insert': '2017-06-27T17:36:43.097Z',
#   'longitude': '-105.3951',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '23',
#   'latitude': '26.93943',
#   'iconcode': '85',
#   'windspeedkm': '8'},
#  {'_id': '5952983359954a0adbf7ab28',
#   'cityid': 'MXCA0342',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'NNO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '45',
#   'name': 'Aquiles Serdán',
#   'date-insert': '2017-06-27T17:36:43.097Z',
#   'longitude': '-105.8875',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '23',
#   'latitude': '28.5945',
#   'iconcode': '85',
#   'windspeedkm': '5'},
#  {'_id': '5952983359954a0adbf7ab29',
#   'cityid': 'MXCA0343',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'SSO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '50',
#   'name': 'Ascensión',
#   'date-insert': '2017-06-27T17:36:43.097Z',
#   'longitude': '-107.9959',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092451Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '24',
#   'latitude': '31.09218',
#   'iconcode': '85',
#   'windspeedkm': '6'},
#  {'_id': '5952983359954a0adbf7ab2a',
#   'cityid': 'MXCA0344',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'NE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '61',
#   'name': 'Bachíniva',
#   'date-insert': '2017-06-27T17:36:43.097Z',
#   'longitude': '-107.2536',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092451Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '19',
#   'latitude': '28.76494',
#   'iconcode': '85',
#   'windspeedkm': '2'},
#  {'_id': '5952983359954a0adbf7ab2b',
#   'cityid': 'MXCA0345',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'NNO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '46',
#   'name': 'Balleza',
#   'date-insert': '2017-06-27T17:36:43.097Z',
#   'longitude': '-106.3469',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '23',
#   'latitude': '26.95411',
#   'iconcode': '85',
#   'windspeedkm': '2'},
#  {'_id': '5952983359954a0adbf7ab2c',
#   'cityid': 'MXCA0346',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'O',
#   'probabilityofprecip': '0',
#   'relativehumidity': '63',
#   'name': 'Batopilas',
#   'date-insert': '2017-06-27T17:36:43.098Z',
#   'longitude': '-107.7397',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '28',
#   'latitude': '27.02665',
#   'iconcode': '85',
#   'windspeedkm': '3'},
#  {'_id': '5952983359954a0adbf7ab2d',
#   'cityid': 'MXCA0347',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'ENE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '57',
#   'name': 'Bocoyna',
#   'date-insert': '2017-06-27T17:36:43.098Z',
#   'longitude': '-107.5893',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '18',
#   'latitude': '27.84074',
#   'iconcode': '85',
#   'windspeedkm': '6'},
#  {'_id': '5952983359954a0adbf7ab2e',
#   'cityid': 'MXCA0348',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'S',
#   'probabilityofprecip': '0',
#   'relativehumidity': '49',
#   'name': 'Buenaventura',
#   'date-insert': '2017-06-27T17:36:43.098Z',
#   'longitude': '-107.4713',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092451Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '24',
#   'latitude': '29.84337',
#   'iconcode': '85',
#   'windspeedkm': '10'},
#  {'_id': '5952983359954a0adbf7ab2f',
#   'cityid': 'MXCA0349',
#   'validdateutc': '20170627T130000Z',
#   'winddirectioncardinal': 'N',
#   'probabilityofprecip': '0',
#   'relativehumidity': '71',
#   'name': 'Carichí',
#   'date-insert': '2017-06-27T17:36:43.098Z',
#   'longitude': '-107.0568',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Mayormente soleado',
#   'stateabbr': 'CHH',
#   'tempc': '15',
#   'latitude': '27.91653',
#   'iconcode': '65',
#   'windspeedkm': '6'},
#  {'_id': '5952983359954a0adbf7ab30',
#   'cityid': 'MXCA0350',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'OSO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '49',
#   'name': 'Casas Grandes',
#   'date-insert': '2017-06-27T17:36:43.099Z',
#   'longitude': '-107.9488',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092451Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '24',
#   'latitude': '30.3757',
#   'iconcode': '85',
#   'windspeedkm': '5'},
#  {'_id': '5952983359954a0adbf7ab31',
#   'cityid': 'MXCA0351',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'SSE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '54',
#   'name': 'Coronado',
#   'date-insert': '2017-06-27T17:36:43.100Z',
#   'longitude': '-105.1583',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '23',
#   'latitude': '26.73762',
#   'iconcode': '85',
#   'windspeedkm': '6'},
#  {'_id': '5952983359954a0adbf7ab32',
#   'cityid': 'MXCA0352',
#   'validdateutc': '20170627T130000Z',
#   'winddirectioncardinal': 'N',
#   'probabilityofprecip': '10',
#   'relativehumidity': '60',
#   'name': 'Coyame del Sotol',
#   'date-insert': '2017-06-27T17:36:43.100Z',
#   'longitude': '-105.0944',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092450Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '22',
#   'latitude': '29.46204',
#   'iconcode': '85',
#   'windspeedkm': '6'},
#  {'_id': '5952983359954a0adbf7ab33',
#   'cityid': 'MXCA0353',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'S',
#   'probabilityofprecip': '0',
#   'relativehumidity': '48',
#   'name': 'La Cruz',
#   'date-insert': '2017-06-27T17:36:43.100Z',
#   'longitude': '-105.1964',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '26',
#   'latitude': '27.86389',
#   'iconcode': '85',
#   'windspeedkm': '8'},
#  {'_id': '5952983359954a0adbf7ab34',
#   'cityid': 'MXCA0354',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'NNE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '56',
#   'name': 'Cuauhtémoc',
#   'date-insert': '2017-06-27T17:36:43.100Z',
#   'longitude': '-106.866',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092450Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '19',
#   'latitude': '28.40631',
#   'iconcode': '85',
#   'windspeedkm': '2'},
#  {'_id': '5952983359954a0adbf7ab35',
#   'cityid': 'MXCA0355',
#   'validdateutc': '20170627T130000Z',
#   'winddirectioncardinal': 'NNO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '70',
#   'name': 'Cusihuiriachi',
#   'date-insert': '2017-06-27T17:36:43.100Z',
#   'longitude': '-106.8367',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Mayormente soleado',
#   'stateabbr': 'CHH',
#   'tempc': '16',
#   'latitude': '28.24111',
#   'iconcode': '65',
#   'windspeedkm': '5'},
#  {'_id': '5952983359954a0adbf7ab36',
#   'cityid': 'MXCA0356',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'SSO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '69',
#   'name': 'Chínipas',
#   'date-insert': '2017-06-27T17:36:43.100Z',
#   'longitude': '-108.5362',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Parcialmente nublado',
#   'stateabbr': 'CHH',
#   'tempc': '28',
#   'latitude': '27.39281',
#   'iconcode': '66',
#   'windspeedkm': '3'},
#  {'_id': '5952983359954a0adbf7ab37',
#   'cityid': 'MXCA0357',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'N',
#   'probabilityofprecip': '0',
#   'relativehumidity': '48',
#   'name': 'Dr. Belisario Domínguez',
#   'date-insert': '2017-06-27T17:36:43.100Z',
#   'longitude': '-106.477',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '23',
#   'latitude': '28.15467',
#   'iconcode': '85',
#   'windspeedkm': '5'},
#  {'_id': '5952983359954a0adbf7ab38',
#   'cityid': 'MXCA0358',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'ONO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '53',
#   'name': 'Galeana',
#   'date-insert': '2017-06-27T17:36:43.101Z',
#   'longitude': '-107.6167',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092451Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '23',
#   'latitude': '30.11295',
#   'iconcode': '85',
#   'windspeedkm': '2'},
#  {'_id': '5952983359954a0adbf7ab39',
#   'cityid': 'MXCA0359',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'NNE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '45',
#   'name': 'Santa Isabel',
#   'date-insert': '2017-06-27T17:36:43.101Z',
#   'longitude': '-106.3681',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '24',
#   'latitude': '28.34335',
#   'iconcode': '85',
#   'windspeedkm': '5'},
#  {'_id': '5952983359954a0adbf7ab3a',
#   'cityid': 'MXCA0360',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'O',
#   'probabilityofprecip': '0',
#   'relativehumidity': '65',
#   'name': 'Gómez Farías',
#   'date-insert': '2017-06-27T17:36:43.101Z',
#   'longitude': '-107.7387',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092451Z',
#   'skydescriptionlong': 'Mayormente soleado',
#   'stateabbr': 'CHH',
#   'tempc': '19',
#   'latitude': '29.35702',
#   'iconcode': '65',
#   'windspeedkm': '0'},
#  {'_id': '5952983359954a0adbf7ab3b',
#   'cityid': 'MXCA0361',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'NNE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '46',
#   'name': 'Gran Morelos',
#   'date-insert': '2017-06-27T17:36:43.101Z',
#   'longitude': '-106.5101',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '23',
#   'latitude': '28.24782',
#   'iconcode': '85',
#   'windspeedkm': '5'},
#  {'_id': '5952983359954a0adbf7ab3c',
#   'cityid': 'MXCA0362',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'NE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '59',
#   'name': 'Guachochi',
#   'date-insert': '2017-06-27T17:36:43.101Z',
#   'longitude': '-107.0694',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Mayormente soleado',
#   'stateabbr': 'CHH',
#   'tempc': '16',
#   'latitude': '26.81915',
#   'iconcode': '65',
#   'windspeedkm': '6'},
#  {'_id': '5952983359954a0adbf7ab3d',
#   'cityid': 'MXCA0363',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'ESE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '56',
#   'name': 'Guadalupe',
#   'date-insert': '2017-06-27T17:36:43.101Z',
#   'longitude': '-106.1018',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092451Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '23',
#   'latitude': '31.39011',
#   'iconcode': '85',
#   'windspeedkm': '6'},
#  {'_id': '5952983359954a0adbf7ab3e',
#   'cityid': 'MXCA0364',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'E',
#   'probabilityofprecip': '0',
#   'relativehumidity': '67',
#   'name': 'Guadalupe y Calvo',
#   'date-insert': '2017-06-27T17:36:43.101Z',
#   'longitude': '-106.9644',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092451Z',
#   'skydescriptionlong': 'Mayormente soleado',
#   'stateabbr': 'CHH',
#   'tempc': '17',
#   'latitude': '26.09452',
#   'iconcode': '65',
#   'windspeedkm': '5'},
#  {'_id': '5952983359954a0adbf7ab3f',
#   'cityid': 'MXCA0365',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'O',
#   'probabilityofprecip': '0',
#   'relativehumidity': '70',
#   'name': 'Guazapares',
#   'date-insert': '2017-06-27T17:36:43.102Z',
#   'longitude': '-108.28',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092451Z',
#   'skydescriptionlong': 'Parcialmente nublado',
#   'stateabbr': 'CHH',
#   'tempc': '22',
#   'latitude': '27.27638',
#   'iconcode': '66',
#   'windspeedkm': '0'},
#  {'_id': '5952983359954a0adbf7ab40',
#   'cityid': 'MXCA0366',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'SE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '65',
#   'name': 'Guerrero',
#   'date-insert': '2017-06-27T17:36:43.102Z',
#   'longitude': '-107.4869',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092451Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '18',
#   'latitude': '28.54819',
#   'iconcode': '85',
#   'windspeedkm': '3'},
#  {'_id': '5952983359954a0adbf7ab41',
#   'cityid': 'MXCA0367',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'ONO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '48',
#   'name': 'Huejotitán',
#   'date-insert': '2017-06-27T17:36:43.102Z',
#   'longitude': '-106.1795',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '22',
#   'latitude': '27.05467',
#   'iconcode': '85',
#   'windspeedkm': '5'},
#  {'_id': '5952983359954a0adbf7ab42',
#   'cityid': 'MXCA0368',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'SO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '60',
#   'name': 'Ignacio Zaragoza',
#   'date-insert': '2017-06-27T17:36:43.102Z',
#   'longitude': '-107.7642',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092451Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '20',
#   'latitude': '29.64321',
#   'iconcode': '85',
#   'windspeedkm': '3'},
#  {'_id': '5952983359954a0adbf7ab43',
#   'cityid': 'MXCA0369',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'SSE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '49',
#   'name': 'Janos',
#   'date-insert': '2017-06-27T17:36:43.102Z',
#   'longitude': '-108.1898',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092450Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '24',
#   'latitude': '30.88726',
#   'iconcode': '85',
#   'windspeedkm': '5'},
#  {'_id': '5952983359954a0adbf7ab44',
#   'cityid': 'MXCA0370',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'E',
#   'probabilityofprecip': '0',
#   'relativehumidity': '41',
#   'name': 'Julimes',
#   'date-insert': '2017-06-27T17:36:43.103Z',
#   'longitude': '-105.4306',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '27',
#   'latitude': '28.42306',
#   'iconcode': '85',
#   'windspeedkm': '6'},
#  {'_id': '5952983359954a0adbf7ab45',
#   'cityid': 'MXCA0371',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'SSE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '55',
#   'name': 'López',
#   'date-insert': '2017-06-27T17:36:43.103Z',
#   'longitude': '-105.0331',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '24',
#   'latitude': '27.0025',
#   'iconcode': '85',
#   'windspeedkm': '11'},
#  {'_id': '5952983359954a0adbf7ab46',
#   'cityid': 'MXCA0373',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'ENE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '53',
#   'name': 'Maguarichi',
#   'date-insert': '2017-06-27T17:36:43.103Z',
#   'longitude': '-107.994',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '22',
#   'latitude': '27.8593',
#   'iconcode': '85',
#   'windspeedkm': '5'},
#  {'_id': '5952983359954a0adbf7ab47',
#   'cityid': 'MXCA0374',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'NNE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '61',
#   'name': 'Manuel Benavides',
#   'date-insert': '2017-06-27T17:36:43.103Z',
#   'longitude': '-103.9078',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092451Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '25',
#   'latitude': '29.10739',
#   'iconcode': '85',
#   'windspeedkm': '3'},
#  {'_id': '5952983359954a0adbf7ab48',
#   'cityid': 'MXCA0375',
#   'validdateutc': '20170627T130000Z',
#   'winddirectioncardinal': 'SE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '87',
#   'name': 'Matachí',
#   'date-insert': '2017-06-27T17:36:43.103Z',
#   'longitude': '-107.7546',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092451Z',
#   'skydescriptionlong': 'Parcialmente nublado',
#   'stateabbr': 'CHH',
#   'tempc': '14',
#   'latitude': '28.84323',
#   'iconcode': '66',
#   'windspeedkm': '2'},
#  {'_id': '5952983559954a0adbf7ab53',
#   'cityid': 'MXCA0376',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'SSO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '51',
#   'name': 'Matamoros',
#   'date-insert': '2017-06-27T17:36:43.103Z',
#   'longitude': '-105.5833',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '22',
#   'latitude': '26.76388',
#   'iconcode': '85',
#   'windspeedkm': '3'},
#  {'_id': '5952983559954a0adbf7ab54',
#   'cityid': 'MXCA0377',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'NNO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '44',
#   'name': 'Meoqui',
#   'date-insert': '2017-06-27T17:36:43.103Z',
#   'longitude': '-105.4803',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '26',
#   'latitude': '28.2678',
#   'iconcode': '85',
#   'windspeedkm': '5'},
#  {'_id': '5952983559954a0adbf7ab55',
#   'cityid': 'MXCA0378',
#   'validdateutc': '20170627T130000Z',
#   'winddirectioncardinal': 'NO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '80',
#   'name': 'Morelos',
#   'date-insert': '2017-06-27T17:36:43.103Z',
#   'longitude': '-107.6772',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Mayormente soleado',
#   'stateabbr': 'CHH',
#   'tempc': '23',
#   'latitude': '26.67053',
#   'iconcode': '65',
#   'windspeedkm': '0'},
#  {'_id': '5952983559954a0adbf7ab56',
#   'cityid': 'MXCA0379',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'ONO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '59',
#   'name': 'Moris',
#   'date-insert': '2017-06-27T17:36:43.104Z',
#   'longitude': '-108.5232',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092451Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '26',
#   'latitude': '28.14838',
#   'iconcode': '85',
#   'windspeedkm': '0'},
#  {'_id': '5952983559954a0adbf7ab57',
#   'cityid': 'MXCA0380',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'SSO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '61',
#   'name': 'Namiquipa',
#   'date-insert': '2017-06-27T17:36:43.104Z',
#   'longitude': '-107.4089',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '21',
#   'latitude': '29.25076',
#   'iconcode': '85',
#   'windspeedkm': '5'},
#  {'_id': '5952983559954a0adbf7ab58',
#   'cityid': 'MXCA0381',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'N',
#   'probabilityofprecip': '0',
#   'relativehumidity': '48',
#   'name': 'Nonoava',
#   'date-insert': '2017-06-27T17:36:43.104Z',
#   'longitude': '-106.7353',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '22',
#   'latitude': '27.47205',
#   'iconcode': '85',
#   'windspeedkm': '3'},
#  {'_id': '5952983559954a0adbf7ab59',
#   'cityid': 'MXCA0382',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'E',
#   'probabilityofprecip': '0',
#   'relativehumidity': '58',
#   'name': 'Ocampo',
#   'date-insert': '2017-06-27T17:36:43.104Z',
#   'longitude': '-108.3667',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092451Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '21',
#   'latitude': '28.19383',
#   'iconcode': '85',
#   'windspeedkm': '5'},
#  {'_id': '5952983559954a0adbf7ab5a',
#   'cityid': 'MXCA0383',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'ENE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '53',
#   'name': 'Ojinaga',
#   'date-insert': '2017-06-27T17:36:43.104Z',
#   'longitude': '-104.4157',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092451Z',
#   'skydescriptionlong': 'Parcialmente nublado',
#   'stateabbr': 'CHH',
#   'tempc': '27',
#   'latitude': '29.5645',
#   'iconcode': '66',
#   'windspeedkm': '2'},
#  {'_id': '5952983559954a0adbf7ab5b',
#   'cityid': 'MXCA0384',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'ESE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '57',
#   'name': 'Praxedis G. Guerrero',
#   'date-insert': '2017-06-27T17:36:43.104Z',
#   'longitude': '-106.0054',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092451Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '23',
#   'latitude': '31.37207',
#   'iconcode': '85',
#   'windspeedkm': '8'},
#  {'_id': '5952983559954a0adbf7ab5c',
#   'cityid': 'MXCA0385',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'NNO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '49',
#   'name': 'Riva Palacio',
#   'date-insert': '2017-06-27T17:36:43.104Z',
#   'longitude': '-106.5026',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '23',
#   'latitude': '28.54601',
#   'iconcode': '85',
#   'windspeedkm': '2'},
#  {'_id': '5952983559954a0adbf7ab5d',
#   'cityid': 'MXCA0386',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'N',
#   'probabilityofprecip': '0',
#   'relativehumidity': '43',
#   'name': 'Rosales',
#   'date-insert': '2017-06-27T17:36:43.104Z',
#   'longitude': '-105.5544',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '27',
#   'latitude': '28.18694',
#   'iconcode': '85',
#   'windspeedkm': '10'},
#  {'_id': '5952983559954a0adbf7ab5e',
#   'cityid': 'MXCA0387',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'NNO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '43',
#   'name': 'Rosario',
#   'date-insert': '2017-06-27T17:36:43.104Z',
#   'longitude': '-106.2955',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '24',
#   'latitude': '27.31964',
#   'iconcode': '85',
#   'windspeedkm': '2'},
#  {'_id': '5952983559954a0adbf7ab5f',
#   'cityid': 'MXCA0388',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'NNO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '47',
#   'name': 'San Francisco de Borja',
#   'date-insert': '2017-06-27T17:36:43.104Z',
#   'longitude': '-106.6849',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '23',
#   'latitude': '27.90182',
#   'iconcode': '85',
#   'windspeedkm': '3'},
#  {'_id': '5952983559954a0adbf7ab60',
#   'cityid': 'MXCA0389',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'SSE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '48',
#   'name': 'San Francisco de Conchos',
#   'date-insert': '2017-06-27T17:36:43.105Z',
#   'longitude': '-105.3346',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '26',
#   'latitude': '27.58855',
#   'iconcode': '85',
#   'windspeedkm': '8'},
#  {'_id': '5952983559954a0adbf7ab61',
#   'cityid': 'MXCA0390',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'N',
#   'probabilityofprecip': '0',
#   'relativehumidity': '47',
#   'name': 'San Francisco del Oro',
#   'date-insert': '2017-06-27T17:36:43.105Z',
#   'longitude': '-105.8501',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '21',
#   'latitude': '26.85899',
#   'iconcode': '85',
#   'windspeedkm': '5'},
#  {'_id': '5952983559954a0adbf7ab62',
#   'cityid': 'MXCA0391',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'NNE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '47',
#   'name': 'Santa Bárbara',
#   'date-insert': '2017-06-27T17:36:43.105Z',
#   'longitude': '-105.8181',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '21',
#   'latitude': '26.8021',
#   'iconcode': '85',
#   'windspeedkm': '3'},
#  {'_id': '5952983559954a0adbf7ab63',
#   'cityid': 'MXCA0392',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'NNE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '42',
#   'name': 'Satevó',
#   'date-insert': '2017-06-27T17:36:43.105Z',
#   'longitude': '-106.1072',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '26',
#   'latitude': '27.95603',
#   'iconcode': '85',
#   'windspeedkm': '5'},
#  {'_id': '5952983559954a0adbf7ab64',
#   'cityid': 'MXCA0393',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'S',
#   'probabilityofprecip': '0',
#   'relativehumidity': '45',
#   'name': 'Saucillo',
#   'date-insert': '2017-06-27T17:36:43.105Z',
#   'longitude': '-105.288',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '27',
#   'latitude': '28.03267',
#   'iconcode': '85',
#   'windspeedkm': '5'},
#  {'_id': '5952983559954a0adbf7ab65',
#   'cityid': 'MXCA0394',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'O',
#   'probabilityofprecip': '0',
#   'relativehumidity': '47',
#   'name': 'El Tule',
#   'date-insert': '2017-06-27T17:36:43.105Z',
#   'longitude': '-106.2663',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '22',
#   'latitude': '27.05361',
#   'iconcode': '85',
#   'windspeedkm': '3'},
#  {'_id': '5952983559954a0adbf7ab66',
#   'cityid': 'MXCA0395',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'NO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '56',
#   'name': 'Urique',
#   'date-insert': '2017-06-27T17:36:43.105Z',
#   'longitude': '-107.9143',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Mayormente soleado',
#   'stateabbr': 'CHH',
#   'tempc': '28',
#   'latitude': '27.21272',
#   'iconcode': '65',
#   'windspeedkm': '2'},
#  {'_id': '5952983559954a0adbf7ab67',
#   'cityid': 'MXCA0396',
#   'validdateutc': '20170627T130000Z',
#   'winddirectioncardinal': 'ENE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '66',
#   'name': 'Uruachi',
#   'date-insert': '2017-06-27T17:36:43.105Z',
#   'longitude': '-108.2152',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Parcialmente nublado',
#   'stateabbr': 'CHH',
#   'tempc': '19',
#   'latitude': '27.86792',
#   'iconcode': '66',
#   'windspeedkm': '10'},
#  {'_id': '5952983559954a0adbf7ab68',
#   'cityid': 'MXCA0397',
#   'validdateutc': '20170627T130000Z',
#   'winddirectioncardinal': 'NO',
#   'probabilityofprecip': '0',
#   'relativehumidity': '53',
#   'name': 'Valle de Zaragoza',
#   'date-insert': '2017-06-27T17:36:43.105Z',
#   'longitude': '-105.811',
#   'state': 'Chihuahua',
#   'lastreporttime': '20170627T092452Z',
#   'skydescriptionlong': 'Soleado',
#   'stateabbr': 'CHH',
#   'tempc': '21',
#   'latitude': '27.45713',
#   'iconcode': '85',
#   'windspeedkm': '3'},
#  {'_id': '5952983559954a0adbf7ab69',
#   'cityid': 'MXCE0008',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'ESE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '83',
#   'name': 'Campeche',
#   'date-insert': '2017-06-27T17:36:43.105Z',
#   'longitude': '-90.53965',
#   'state': 'Campeche',
#   'lastreporttime': '20170627T092449Z',
#   'skydescriptionlong': 'Parcialmente nublado',
#   'stateabbr': 'CAM',
#   'tempc': '27',
#   'latitude': '19.84481',
#   'iconcode': '66',
#   'windspeedkm': '13'},
#  {'_id': '5952983559954a0adbf7ab6a',
#   'cityid': 'MXCE0009',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'ESE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '83',
#   'name': 'Carmen',
#   'date-insert': '2017-06-27T17:36:43.105Z',
#   'longitude': '-91.83645',
#   'state': 'Campeche',
#   'lastreporttime': '20170627T092449Z',
#   'skydescriptionlong': 'Parcialmente nublado',
#   'stateabbr': 'CAM',
#   'tempc': '27',
#   'latitude': '18.63779',
#   'iconcode': '66',
#   'windspeedkm': '18'},
#  {'_id': '5952983559954a0adbf7ab6b',
#   'cityid': 'MXCE0184',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'ESE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '78',
#   'name': 'Calkiní',
#   'date-insert': '2017-06-27T17:36:43.106Z',
#   'longitude': '-90.05074',
#   'state': 'Campeche',
#   'lastreporttime': '20170627T092450Z',
#   'skydescriptionlong': 'Parcialmente nublado',
#   'stateabbr': 'CAM',
#   'tempc': '28',
#   'latitude': '20.37123',
#   'iconcode': '66',
#   'windspeedkm': '16'},
#  {'_id': '5952983559954a0adbf7ab6c',
#   'cityid': 'MXCE0185',
#   'validdateutc': '20170627T130000Z',
#   'winddirectioncardinal': 'ESE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '88',
#   'name': 'Champotón',
#   'date-insert': '2017-06-27T17:36:43.106Z',
#   'longitude': '-90.72389',
#   'state': 'Campeche',
#   'lastreporttime': '20170627T092500Z',
#   'skydescriptionlong': 'Parcialmente nublado',
#   'stateabbr': 'CAM',
#   'tempc': '26',
#   'latitude': '19.35622',
#   'iconcode': '66',
#   'windspeedkm': '10'},
#  {'_id': '5952983559954a0adbf7ab6d',
#   'cityid': 'MXCE0186',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'ESE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '78',
#   'name': 'Hecelchakán',
#   'date-insert': '2017-06-27T17:36:43.106Z',
#   'longitude': '-90.13451',
#   'state': 'Campeche',
#   'lastreporttime': '20170627T092500Z',
#   'skydescriptionlong': 'Parcialmente nublado',
#   'stateabbr': 'CAM',
#   'tempc': '28',
#   'latitude': '20.17697',
#   'iconcode': '66',
#   'windspeedkm': '16'},
#  {'_id': '5952983559954a0adbf7ab6e',
#   'cityid': 'MXCE0187',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'ESE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '80',
#   'name': 'Hopelchén',
#   'date-insert': '2017-06-27T17:36:43.106Z',
#   'longitude': '-89.84505',
#   'state': 'Campeche',
#   'lastreporttime': '20170627T092450Z',
#   'skydescriptionlong': 'Parcialmente nublado',
#   'stateabbr': 'CAM',
#   'tempc': '27',
#   'latitude': '19.74555',
#   'iconcode': '66',
#   'windspeedkm': '11'},
#  {'_id': '5952983559954a0adbf7ab6f',
#   'cityid': 'MXCE0188',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'ESE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '82',
#   'name': 'Palizada',
#   'date-insert': '2017-06-27T17:36:43.106Z',
#   'longitude': '-92.0909',
#   'state': 'Campeche',
#   'lastreporttime': '20170627T092451Z',
#   'skydescriptionlong': 'Parcialmente nublado',
#   'stateabbr': 'CAM',
#   'tempc': '27',
#   'latitude': '18.2536',
#   'iconcode': '66',
#   'windspeedkm': '11'},
#  {'_id': '5952983559954a0adbf7ab70',
#   'cityid': 'MXCE0189',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'ESE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '78',
#   'name': 'Tenabo',
#   'date-insert': '2017-06-27T17:36:43.106Z',
#   'longitude': '-90.22576',
#   'state': 'Campeche',
#   'lastreporttime': '20170627T092500Z',
#   'skydescriptionlong': 'Parcialmente nublado',
#   'stateabbr': 'CAM',
#   'tempc': '28',
#   'latitude': '20.03968',
#   'iconcode': '66',
#   'windspeedkm': '13'},
#  {'_id': '5952983559954a0adbf7ab71',
#   'cityid': 'MXCE0190',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'ESE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '83',
#   'name': 'Escárcega',
#   'date-insert': '2017-06-27T17:36:43.107Z',
#   'longitude': '-90.732',
#   'state': 'Campeche',
#   'lastreporttime': '20170627T092500Z',
#   'skydescriptionlong': 'Parcialmente nublado',
#   'stateabbr': 'CAM',
#   'tempc': '27',
#   'latitude': '18.60431',
#   'iconcode': '66',
#   'windspeedkm': '10'},
#  {'_id': '5952983559954a0adbf7ab72',
#   'cityid': 'MXCE2460',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'ESE',
#   'probabilityofprecip': '0',
#   'relativehumidity': '84',
#   'name': 'Candelaria',
#   'date-insert': '2017-06-27T17:36:43.107Z',
#   'longitude': '-91.0463',
#   'state': 'Campeche',
#   'lastreporttime': '20170627T092451Z',
#   'skydescriptionlong': 'Parcialmente nublado',
#   'stateabbr': 'CAM',
#   'tempc': '27',
#   'latitude': '18.18345',
#   'iconcode': '66',
#   'windspeedkm': '11'},
#  {'_id': '5952983559954a0adbf7ab73',
#   'cityid': 'MXCL0010',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'E',
#   'probabilityofprecip': '20',
#   'relativehumidity': '82',
#   'name': 'Acuña',
#   'date-insert': '2017-06-27T17:36:43.108Z',
#   'longitude': '-100.9783',
#   'state': 'Coahuila',
#   'lastreporttime': '20170627T092450Z',
#   'skydescriptionlong': 'Mayormente nublado',
#   'stateabbr': 'COA',
#   'tempc': '26',
#   'latitude': '29.33001',
#   'iconcode': '69',
#   'windspeedkm': '11'},
#  {'_id': '5952983559954a0adbf7ab74',
#   'cityid': 'MXCL0011',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'NNO',
#   'probabilityofprecip': '20',
#   'relativehumidity': '57',
#   'name': 'Monclova',
#   'date-insert': '2017-06-27T17:36:43.108Z',
#   'longitude': '-101.4172',
#   'state': 'Coahuila',
#   'lastreporttime': '20170627T092449Z',
#   'skydescriptionlong': 'Parcialmente nublado',
#   'stateabbr': 'COA',
#   'tempc': '26',
#   'latitude': '26.90124',
#   'iconcode': '66',
#   'windspeedkm': '10'},
#  {'_id': '5952983559954a0adbf7ab75',
#   'cityid': 'MXCL0012',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'ENE',
#   'probabilityofprecip': '20',
#   'relativehumidity': '79',
#   'name': 'Piedras Negras',
#   'date-insert': '2017-06-27T17:36:43.108Z',
#   'longitude': '-100.5284',
#   'state': 'Coahuila',
#   'lastreporttime': '20170627T092450Z',
#   'skydescriptionlong': 'Mayormente nublado',
#   'stateabbr': 'COA',
#   'tempc': '26',
#   'latitude': '28.70809',
#   'iconcode': '69',
#   'windspeedkm': '8'},
#  {'_id': '5952983559954a0adbf7ab76',
#   'cityid': 'MXCL0013',
#   'validdateutc': '20170627T140000Z',
#   'winddirectioncardinal': 'NE',
#   'probabilityofprecip': '20',
#   'relativehumidity': '62',
#   'name': 'Saltillo',
#   'date-insert': '2017-06-27T17:36:43.108Z',
#   'longitude': '-100.9997',
#   'state': 'Coahuila',
#   'lastreporttime': '20170627T092450Z',
#   'skydescriptionlong': 'Parcialmente nublado',
#   'stateabbr': 'COA',
#   'tempc': '21',
#   'latitude': '25.42167',
#   'iconcode': '66',
#   'windspeedkm': '0'}]

# %%
df = pd.DataFrame(data['results'])

# %%
df.shape
# Out:
# (100, 17)

# %%
df.dtypes
# Out:
# _id                      object
# cityid                   object
# date-insert              object
# iconcode                 object
# lastreporttime           object
# latitude                 object
# longitude                object
# name                     object
# probabilityofprecip      object
# relativehumidity         object
# skydescriptionlong       object
# state                    object
# stateabbr                object
# tempc                    object
# validdateutc             object
# winddirectioncardinal    object
# windspeedkm              object
# dtype: object

# %%
df.longitude = df.longitude.astype(float)
df.latitude = df.latitude.astype(float)
df.tempc = df.tempc.astype(float)

# %%
df.tempc.describe()
# Out:
# count    100.000000
# mean      22.700000
# std        3.886002
# min       14.000000
# 25%       19.750000
# 50%       23.000000
# 75%       26.000000
# max       32.000000
# Name: tempc, dtype: float64

# %%
gdf = gpd.GeoDataFrame(df)

# %%
# Useful snippet to re-use:

gdf['geometry'] = list(zip(df.longitude, df.latitude))
gdf['geometry'] = [Point(geom) for geom in gdf.geometry]

# %%
df.tempc.value_counts().sort_index(ascending = True).plot(kind = 'barh')
plt.title('Latest temperatures in Mexico');

# %%
ax = gdf.plot(column = 'tempc', colormap = 'viridis')
mpll.display(fig = ax.figure)
# Out:
# /Users/nicholasjones/anaconda3/envs/GPD_OSM/lib/python3.7/site-packages/geopandas/plotting.py:396: FutureWarning: 'colormap' is deprecated, please use 'cmap' instead (for consistency with matplotlib)
#   "(for consistency with matplotlib)", FutureWarning)
# /Users/nicholasjones/anaconda3/envs/GPD_OSM/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src="data:text/html;base64,..." width="100%" height="240"></iframe>

# %%
f, ax1 = plt.subplots(figsize = [8,0.5])
norm = mpl.colors.Normalize(df.tempc.min(), df.tempc.max())
cb1 = mpl.colorbar.ColorbarBase(ax1, norm = norm, cmap='viridis',
                                orientation='horizontal')
cb1.set_label('Temperatures')

# %% [markdown]
# Documentation:
# * the requests library ([click here](https://realpython.com/python-requests/))
# * Pandas: [value_counts](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html), [df.plot()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html)
# * [customizing colorbars](https://jakevdp.github.io/PythonDataScienceHandbook/04.07-customizing-colorbars.html)
# * [convert lat / lon columns to Geometry](https://medium.com/@shakasom/how-to-convert-latitude-longtitude-columns-in-csv-to-geometry-column-using-python-4219d2106dea)

# %% [markdown]
# ## Worked example 3: OSM locations
# **Objective:** Create an Area of Interest, download OpenStreetMap points of interest, intersect them with administrative boundaries

# %% [markdown]
# **Step 1: create an Area of Interest using www.geojson.io**

# %%
my_geojson = {
  "type": "FeatureCollection",
  "features": [
    {
      "type": "Feature",
      "properties": {},
      "geometry": {
        "type": "Polygon",
        "coordinates": [
          [
            [
              -99.16671752929688,
              19.690435317911682
            ],
            [
              -99.43038940429686,
              19.508020154916768
            ],
            [
              -99.40155029296875,
              19.27744323287618
            ],
            [
              -99.25735473632812,
              19.182786626300352
            ],
            [
              -98.94012451171875,
              19.156843799897302
            ],
            [
              -98.81515502929688,
              19.540378338405763
            ],
            [
              -98.9208984375,
              19.730512997022263
            ],
            [
              -99.16671752929688,
              19.690435317911682
            ]
          ]
        ]
      }
    }
  ]
}

# %%
gdf = gpd.GeoDataFrame.from_features(my_geojson)

# %%
ax = gdf.plot()
mpll.display(fig = ax.figure)
# Out:
# /Users/nicholasjones/anaconda3/envs/GPD_OSM/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src="data:text/html;base64,..." width="100%" height="240"></iframe>

# %%
my_geom = gdf.geometry[0]

# %%
my_geom

# %%
pois = ox.pois_from_polygon(my_geom, ['hospital'])

# %%
pois = pois[['name','geometry']]

# %%
print("Found {} hospitals in AOI.".format(len(pois)))
pois.head()
# Out:
# Found 370 hospitals in AOI.
#                              name                               geometry
# 319436637  Hospital San Angel Inn  POINT (-99.19984100000001 19.3403526)
# 326573871                     NaN         POINT (-99.1676539 19.3588619)
# 331600009          Santa Teresita         POINT (-99.2063529 19.4223048)
# 364459687                    IMSS         POINT (-99.2067819 19.5433839)
# 471092318       Sanatorio Durango         POINT (-99.1729587 19.4191311)

# %% [markdown]
# YOUR ACTION:
#
# * Go to www.GeoJSON.io and draw a Polygon around an area that interests you.
# * Copy the text onto your clipboard.
# * Paste it over the GeoJSON content above.
#
# Then:
# * Create a new dataframe 'schools', download OSM school locations to it
# * Create a dataframe 'hospitals', do the same
# * Plot the dataframes on the same figure (schools in red, hospitals in blue)

# %% [markdown]
# #### Spatial joins - merge locations with Mexico City districts
# Geopandas lets you merge two sets of features based on their spatial relationship with each other (eg. are the points located within the Polygons?).

# %%
CDMX_districts = gpd.read_file('data/CDMX_shp/df_municipio.shp')
CDMX_districts = CDMX_districts[['NOMGEO','geometry']]

# %%
ax = CDMX_districts.plot(figsize = [6,6])
pois.plot(color = 'r', alpha = 0.5, ax = ax)
plt.title('Hospitals and district boundaries');

# %% [markdown]
# **--> NOTE, we have some hospitals outside the boundaries.**
# * Use a spatial join to merge the two dataframes by location.
# * For each hospital, keep name of the district that contains it.

# %%
pois = gpd.sjoin(pois, CDMX_districts)
print("After spatial join, we have {} hospitals.".format(len(pois)))
pois.head()
# Out:
# After spatial join, we have 245 hospitals.
# /Users/nicholasjones/anaconda3/envs/GPD_OSM/lib/python3.7/site-packages/geopandas/tools/sjoin.py:56: UserWarning: CRS of frames being joined does not match!(+proj=longlat +ellps=WGS84 +datum=WGS84 +no_defs != {'init': 'epsg:4326'})
#   '(%s != %s)' % (left_df.crs, right_df.crs))
#                                                          name  \
# 319436637                              Hospital San Angel Inn
# 739035810                                                IMSS
# 2324519237                   Hospital General Enrique Cabrera
# 3977351148                                                NaN
# 4375486092  Hospital General Dr. Fernando Quiroz Gutiérrez...
#
#                                          geometry  index_right          NOMGEO
# 319436637   POINT (-99.19984100000001 19.3403526)            3  Álvaro Obregón
# 739035810          POINT (-99.2002517 19.3368831)            3  Álvaro Obregón
# 2324519237         POINT (-99.2243126 19.3615894)            3  Álvaro Obregón
# 3977351148  POINT (-99.27267089999999 19.3290459)            3  Álvaro Obregón
# 4375486092         POINT (-99.1941336 19.3943089)            3  Álvaro Obregón

# %%
pois.NOMGEO.value_counts().sort_values(ascending = True).plot(kind = 'barh')
plt.title("Mexico City: hospitals per district (according to OSM)")
# Out:
# Text(0.5, 1.0, 'Mexico City: hospitals per district (according to OSM)')

# %%
Documentation:
* [Spatial joins concept][http://wiki.gis.com/wiki/index.php/Spatial_Join]
* Geopandas [.sjoin()](http://geopandas.org/mergingdata.html) function.
# Out:
#   File "<ipython-input-213-7dd14bc10eb7>", line 1
#     Documentation:
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Part 2: Working with sample weights
#
# The data below is from the Nigeria General Household Survey - Wave 3 (2015-2016). It's [available](http://microdata.worldbank.org/index.php/catalog/2936/datafile/F11) on the WB Microdata Library.
#
# With household survey data, sample weights are important to generalize from the sample to the population.
#
# **Objective: Calculate and visualize average food consumption across Nigeria's regions**

# %%
from IPython.display import Image
Image('data/nigeria_table.png', width = 250)

# %%
df2 = pd.read_csv('data/food2_pc.csv')

df2.rename(columns = {'hhweight':'household_weight','hhsize':'household_size','food_tot_pc':'food_consumption_pc',
           'food_purch_pc':'food_purchased_pc','indweight':'individual_weight'}, inplace=True)

df2.sector.replace({'1. URBAN': 'urban', '2. RURAL':'rural'}, inplace=True)
df2.zone.replace({'4. SOUTH EAST':'south_east', '2. NORTH EAST':'north_east', '5. SOUTH SOUTH':'south_south',
       '1. NORTH CENTRAL':'north_central', '6. SOUTH WEST':'south_west', '3. NORTH WEST':'north_west'}, inplace = True)

# %%
df2.head(2)
# Out:
#     hhid sector        zone  household_weight  household_size  \
# 0  10001  urban  south_east      11898.656886               6
# 1  10002  urban  south_east      11898.656886               5
#
#    food_consumption_pc  food_purchased_pc  year  individual_weight
# 0             66134.52           66134.52  2016           71391.94
# 1            154360.40          154360.40  2016           59493.29

# %% [markdown]
# #### 1. Inspect data and remove outliers

# %%
df2.food_consumption_pc.hist()

# %%
df2[['food_purchased_pc', 'food_consumption_pc']].boxplot(figsize = [4,4])

# %%
print(df2.food_purchased_pc.max())
print(df2.food_purchased_pc.mean())
# Out:
# 48200000.0
# 71520.49595792315

# %%
# Remove observations more than 3 standard deviations above the mean

df2['food_purchased_pc'][df2['food_purchased_pc'] > (df2.food_purchased_pc.mean() + df2.food_purchased_pc.std() * 3)] = np.nan
df2['food_consumption_pc'][df2['food_consumption_pc'] > (df2.food_consumption_pc.mean() + df2.food_consumption_pc.std() * 3)] = np.nan
df2.dropna(inplace = True)
# Out:
# /Users/nicholasjones/anaconda3/envs/GPD_OSM/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/nicholasjones/anaconda3/envs/GPD_OSM/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# #### 2. Calculate mean food consumption by region, and by rural / urban.
#
# The Pandas groupby function makes this easy. Read the [docs](http://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html).
#
# It does three things:
# * Split the data into groups.
# * Applie a function to each group independently (eg. sum, mean, counts).
# * Combine the results into a data structure.

# %%
df2.groupby(['zone'])['food_consumption_pc'].mean().sort_values().plot(kind = 'barh')
plt.title('Food consumption per capita, ');

# %%
Image(filename='data/stop.png')

# %% [markdown]
# The data is not representative of the population as a whole, until you apply sample weights!

# %% [markdown]
# #### 3. Calculate mean food consumption for population (not just sampled households)
#
# Weighted mean:
#
# $$\overline x = \frac{\sum wx}{\sum w}$$
#
# ie. sum of values times weights / sum of weights

# %%
sum(df2.food_purchased_pc * df2.individual_weight) / df2.household_weight.sum()
# Out:
# 289663.4699519813

# %%
def weighted_mean(values, weights):
    return sum(values * weights) / weights.sum()

# %%
weighted_mean(df2.food_consumption_pc[df2.zone == zone],
                                  df2.household_weight[df2.zone == zone])
# Out:
# 57854.86206487545

# %%
weighted_means_table = pd.Series({zone: weighted_mean(df2.food_consumption_pc[df2.zone == zone],
                                  df2.household_weight[df2.zone == zone]) for zone in df2.zone.unique()},
                                name = 'mean_food_consumption_pc')

# %%
weighted_means_table.sort_values(ascending = True).plot(kind='barh')
plt.title('Median food consumption by region');

# %% [markdown]
# #### 4. Visualize on a map of Nigeria
# A good data source is GADM, which has admin boundaries for all countries at levels 0 through 3 (national boundaries through to ward level).
#
# We will use GADM level 1 for Nigeria, which includes the 36 states and Federal Capital Territory. https://gadm.org/
#
# Unfortunately our data uses six regions, so we need to create this aggregation manually.

# %%
nigeria_GADM = gpd.read_file('data/nigeria/gadm36_NGA_1.shp')

# %%
nigeria_GADM.NAME_1.nunique()
# Out:
# 37

# %%
north_central = ['Benue','Kogi','Kwara', 'Nassarawa', 'Niger','Plateau', 'Federal Capital Territory']
north_east = ['Adamawa', 'Bauchi', 'Borno', 'Gombe', 'Taraba', 'Yobe']
north_west = ['Jigawa', 'Kaduna', 'Kano', 'Katsina', 'Kebbi', 'Sokoto', 'Zamfara']
south_east = ['Abia', 'Anambra', 'Ebonyi', 'Enugu', 'Imo']
south_south = ['Akwa Ibom', 'Bayelsa', 'Cross River', 'Rivers', 'Delta', 'Edo']
south_west = ['Ekiti', 'Lagos', 'Ogun', 'Ondo', 'Osun', 'Oyo']

def remap_states(state):
    if state in north_east:
        return('north_east')
    elif state in north_central:
        return('north_central')
    elif state in north_west:
        return('north_west')
    elif state in south_east:
        return('south_east')
    elif state in south_south:
        return('south_south')
    elif state in south_west:
        return('south_west')
    else:
        return('error!')

# %% [markdown]
# A quick way to transform the rows or columns of a DataFrame is df.apply(). This runs a function of your choice across all the rows (axis = 0, the default) or all the columns (axis = 1).

# %%
nigeria_GADM['region'] = borders.NAME_1.apply(remap_states)

# %%
nigeria_GADM.plot()

# %%
regions = borders.dissolve(by = 'region')

# %%
regions.plot()

# %%
regions.shape
# Out:
# (6, 11)

# %%
weighted_means_table
# Out:
# south_east        94194.884480
# north_east        62435.831311
# south_south      120569.881613
# north_central     69593.582974
# south_west        89461.149576
# north_west        57854.862065
# Name: mean_food_consumption_pc, dtype: float64

# %%
regions_merged = pd.merge(regions, weighted_means_table, left_index=True, right_index=True)

# %%
regions_merged = gpd.GeoDataFrame(regions_merged)

# %%
regions_merged.plot(column = 'mean_food_consumption_pc', legend = True, figsize = [12,8])
plt.title('Mean food consumption per capita - regions of Nigeria');

# %% [markdown]
# Documentation:
# * pandas [groupby](https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html) function
# * pandas [apply](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.apply.html) function.
# * [choropleth](http://geopandas.org/mapping.html) maps in Geopandas
# * [selecting and slicing data](https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#boolean-indexing) in Pandas
